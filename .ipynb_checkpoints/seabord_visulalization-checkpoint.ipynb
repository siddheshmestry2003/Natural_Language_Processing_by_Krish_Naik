# %% [markdown]
# ## seaborn
# ### seaborn is a python visualization library based on matplotlib that proide a high level interface for drawing attractive and informative statistical fraphiical.seaboarn helps in creating complex vusualization with just a few lines of code .in this lesson ,we eill cover the basics of seaborn including creating various types of plotes and customizing them

# %%
import seaborn as sns

# %%
# Out:
#   Cell In[5], line 1
#     seaborn version__
#             ^
# SyntaxError: invalid syntax

# %%
pip show seaborn
# Out:
# Name: seaborn
# Version: 0.13.2
# Summary: Statistical data visualization
# Home-page:
# Author:
# Author-email: Michael Waskom <mwaskom@gmail.com>
# License:
# Location: C:\Users\siddh\anaconda3\Lib\site-packages
# Requires: matplotlib, numpy, pandas
# Required-by:
# Note: you may need to restart the kernel to use updated packages.

# %%
# basic ploting
tips=sns.load_dataset('tips')
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
# crate a scatter
import matplotlib.pyplot as plt

sns.scatterplot(x='total_bill',y='tip',data=tips)
print("scatter plot is total bill vs tip")
# Out:
# scatter plot is total bill vs tip

# %%
# line plot

sns.lineplot(x='size',y='tip',data=tips)
pl

sns.lineplot(x='size',y='total_bill',data=tips)
# Out:
# <Axes: xlabel='size', ylabel='tip'>

# %%
# categorical plot
#barplot

sns.barplot(x='day',y='total_bill',data=tips)
plt.title('bar plot of total bijll by day')
# Out:
# Text(0.5, 1.0, 'bar plot of total bijll by day')

# %%
# box plot

sns.boxplot(x='day',y='total_bill',data=tips)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
# to show distribution we can use violinplot

sns.violinplot(x='day',y='total_bill',data=tips)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
# histogram
sns.histplot(tips['total_bill'],bins=10,kde=True)
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
# histogram

sns.histplot(tips['total_bill'],bins=10)
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
#kde plot
sns.kdeplot(tips['total_bill'],fill=True)
# Out:
# <Axes: xlabel='total_bill', ylabel='Density'>

# %%
# pairplot
sns.pairplot(data=tips)

# %%
correlation=tips[['total_bill','tip','size']].corr()
correlation
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
# heatmap
correlation=tips[['total_bill','tip','size']].corr()
sns.heatmap(correlation,annot=True)
# Out:
# <Axes: >

# %%
import pandas as pd
df=pd.read_csv("sales.csv")
df.head()
# Out:
#          Date              Product     Category  Units Sold  Unit Price  \
# 0  2025-09-01       Wireless Mouse  Electronics          25         799
# 1  2025-09-01       Cotton T-Shirt      Apparel          40         499
# 2  2025-09-02  Notebook Stationery   Stationery          60          99
# 3  2025-09-02           Smartphone  Electronics          10       14999
# 4  2025-09-03        Running Shoes     Footwear          15        2999
#
#    Total Revenue Region
# 0          19975  North
# 1          19960   West
# 2           5940  South
# 3         149990   East
# 4          44985  North

# %%
# plot total sales by product
plt.figure(figsize=(10.5,6))
sns.barplot(x='Category',y='Total Revenue',data=df,estimator=sum)
# Out:
# <Axes: xlabel='Category', ylabel='Total Revenue'>

# %% [markdown]
# ###
